# %%
name = 'Philip Carmine'
dob = '31 January 1991'
address = '123 Test Street, Geelong 3220'
phone = '0411245675'
email = 'philip.carmine@accenture.com'
qualifications = "I have a certificate 3 in hospitality from Holmsglen institute, I studied there from May 2020 to December 2020"
work_experience = "I worked at McDonalds as a burger maker from July 2019 to April 2021. I then got a job as a bar tender at the Geelong Hotel from April 2021 to July 2021"
skills = "I am good at maths, I know how to clean kitchens, I can design buildings on CAD, I can build statistical programs in R"
interests = "I love computer games, I am interested in theoretical mathematics, I like going to the beach, I am interested in space exploration"
disabilities = "I have autism and have dyslexia"

# %%
import openai

# Set your API key
api_key = "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"
openai.api_key = api_key

# Define the conversation
conversation = [
    {"role": "system", "content": "You are a helpful assistant that generates CVs."},
    {"role": "user", "content": "Please generate a CV based on the following information:"},
    {"role": "assistant", "content": """
    Name: Philip Carmine
    DOB: 31 January 1991
    Address: 123 Test Street, Geelong 3220
    Email: philip.carmine@accenture.com
    Phone: 0411245675
    Experience: I worked at McDonalds as a burger maker from July 2019 to April 2021. I then got a job as a bar tender at the Geelong Hotel from April 2021 to July 2021
    Skills: I am good at maths, I know how to clean kitchens, I can design buildings on CAD, I can build statistical programs in R
    Interests: I love computer games, I am interested in theoretical mathematics, I like going to the beach, I am interested in space exploration
    Qualifications: I have a certificate 3 in hospitality from Holmsglen institute, I studied there from May 2020 to December 2020
    Disabilities: I have autism and have dyslexia
    """}
]

# Generate the CV
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=conversation,
)

# Extract the generated CV
cv = response['choices'][0]['message']['content']

# Print the CV
print(cv)
# Out:
# Philip Carmine
# 123 Test Street, Geelong 3220
# philip.carmine@accenture.com
# 0411245675
#
# Objective:
# Motivated and detail-oriented individual with strong mathematical, design, and programming skills, seeking a challenging position to utilize and further enhance my abilities. Committed to delivering outstanding results and eager to contribute to a dynamic team environment.
#
# Experience:
# Burger Maker, McDonald's
# July 2019 - April 2021
# - Prepared a wide range of burgers according to customer orders with precision and efficiency
# - Upheld high standards of food quality and cleanliness in the kitchen area
# - Collaborated with team members to ensure smooth operations during busy periods
# - Provided exceptional customer service, ensuring customer satisfaction
#
# Bar Tender, Geelong Hotel
# April 2021 - July 2021
# - Prepared and served a variety of alcoholic and non-alcoholic beverages to customers
# ...

# %%
# Modify the CV with a location change
modified_conversation = conversation + [
    {"role": "user", "content": "You changed the location of the McDonald's back to Geelong. I need the location of the McDonald's to be Altona and the city on my address to be Geelong."}
]

# Generate the modified CV
modified_response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=modified_conversation,
)

# Extract the modified CV
modified_cv = modified_response['choices'][0]['message']['content']

# Print the modified CV
print("\nModified CV:")
print(modified_cv)
# Out:
# Modified CV:
# Certainly! Here is your revised CV:
#
# ----------
#
# Name: Philip Carmine
# DOB: 31 January 1991
# Address: 123 Test Street, Geelong 3220
# Email: philip.carmine@accenture.com
# Phone: 0411245675
#
# Experience:
# - Burger Maker, McDonald's (Altona, Victoria)
#   July 2019 to April 2021
# - Bartender, Geelong Hotel (Geelong, Victoria)
#   April 2021 to July 2021
#
# Skills:
# - Excellent mathematical abilities
# - Proficient in kitchen cleaning and hygiene practices
# - Skilled in CAD for building design purposes
# - Experienced in developing statistical programs using R programming language
#
# Interests:
# - Computer games
# - Theoretical mathematics
# - Beach activities
# - Space exploration
#
# Qualifications:
# - Certificate III in Hospitality, Holmesglen Institute
#   May 2020 to December 2020
#
# Disabilities:
# - Autism
# - Dyslexia
#
# ----------
#
# ...
