# %%
# Your request parameters
job_title = "Senior Data Analyst"  # Set the job title dynamically
company = "Victorian Legal Services Board and Commissioner"
job_description = """
Senior Data Analyst

    Victorian Legal Services Board and Commissioner · Melbourne, Victoria, Australia

A$116,000/yr - A$128,000/yr  Hybrid  Full-time  Mid-Senior level
About the job
*Please note that salary is exclusive of superannuation

Can you tell me more about what you do at VLSB+C?

Great question! We're really proud of the work we do. We are the regulator of the Victorian legal profession. We license lawyers and oversee service standards and conduct. This includes handling complaints about lawyers, investigating poor conduct and overseeing management of trust accounts. We are also the stewards of the public purpose and fidelity funds and administer these to support legal regulation and access to justice in Victoria.

We are a modern best practice regulator, using data and insights to help identify where our actions can have the greatest impact on ensuring ethical and professional legal practice by Victorian lawyers. We are passionate about maintaining and protecting the rule of law by ensuring the integrity of the legal profession.

What role are you recruiting for?

We're looking for a Senior Data Analyst to join our Data & Insights Team. You will focus on providing technical expertise in statistical and data analytics to increase the efficiency and accuracy of regulatory, compliance, and educational programs. 

What type of person are you looking for?

We are looking for candidates with the following
•	Relevant qualification in information technology, S.T.E.M., statistics, data science / business analystics or economics / econometrics or relevant experience
•	Experience in data analytics methodologies, techniques and analytics software
•	Experience in programming languages, statistical, data visualisation programs and reporting software

How are you different from other organisations?

We offer:
•	Flexibility: We have work leading edge flexible working options including part-time, compressed hours, flexible start time, up to 3 days working from home.
•	Culture: Our culture results are better than the wider VPS by an average of 10%
•	Well-being: We have an active Social Club and Health and Wellbeing Committee that promote fun and engaging activities throughout the year
•	Partnership: our horizontal structure allows for more partnership with your colleagues and other teams
•	Purpose: We play a key role in regulating the legal practice in Victoria

I want to know more!

Alex Codoreanu would love to hear from you on 03 7039 8407 if you have questions about the role.

I'm now really interested!

Our recruitment is all about red carpet not red tape so simply click on ‘Apply Now' before midnight 22nd October.

Please note that a work task will be organised.

Other relevant information:

Appointment will be subject to abiding by our Flexible Working Procedure which defines the number of required in-office days at Level 5, 555 Bourke Street (including the ‘team day' of your team) and completion of both the VPS Pre-Employment Statutory Declaration, Misconduct Declaration and Consent Form and the Pre-Employment Health Declaration.

Your appointment may be subject to a satisfactory National Police Record Check, provision of evidence of qualifications required for your position and/or a probation period.

VLSB+C is committed to equal employment opportunity, ethical practice, diversity, inclusion and providing reasonable adjustments for persons with disabilities. 

If you have any questions or need assistance to fully participate in the process, please contact People and Culture on 03 9679 8073 or peopleandculture@lsbc.vic.gov.au

    """  # Set the job description dynamically

cv = """
CV - Philip Carmine
Philip Carmine

Address: 80 Burdoo Drive Grovedale
Email: philip.carmine@gmail.com
Phone: 0409 371 641

Objective:
Motivated and experienced data engineering analyst with a strong background in Python programming, SQL querying, and machine learning. Seeking a challenging position where I can leverage my skills to drive data-driven decision making.

Experience:
Senior Data Engineering Analyst, Accenture
November 2021 - Present

- Develop and maintain data pipelines for large-scale data processing and analysis.
- Collaborate with cross-functional teams to identify business requirements and implement data solutions.
- Conduct data quality assessments and implement strategies to improve data integrity and accuracy.
- Utilize Python and SQL to build data models and perform advanced data analysis.

Data Analyst Programmer, Barwon Water
September 2018 - November 2021

- Gathered and analyzed data to identify trends, patterns, and insights for informed decision making.
- Developed and maintained data queries in SQL to extract, transform, and load data from various sources.
- Built predictive models using machine learning software to forecast water consumption patterns.
- Collaborated with stakeholders to develop reporting dashboards and visualizations for data-driven insights.

Education:
Master of Data Science, Monash University
June 2018 - June 2023

Skills:
- Proficient in Python programming for data analysis and automation.
- Strong ability to develop complex queries in SQL for data extraction and manipulation.
- Experience in building and deploying machine learning models using popular libraries.
- Excellent problem-solving skills with a strategic mindset to drive data-driven decision making.

Interests:
In my free time, I enjoy surfing and camping. I am also an active member of the Jan Juc cricket club, where I currently hold the position of club secretary.

Disabilities:
I have dyslexia and mobility issues. However, with accommodations and assistive technology, I have successfully excelled in my professional career.

"""  # Replace with the actual CV content

# %%
import openai

# Set your OpenAI API key
api_key = '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'

openai.api_key = api_key

messages = [
    {"role": "system", "content": "You are a helpful assistant that is great at writing cover letters for job applications."},
    {"role": "user", "content": f"Please draft a cover letter for me for the position described in {job_description} based on the information that I have provided in my CV {cv}."},
    {"role": "assistant", "content": cv},  # Include the CV content here
    {"role": "assistant", "content": job_description},
]

# Make the API request
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages,
)

# Extract the assistant's reply
assistant_reply = response['choices'][0]['message']['content']

# Print the assistant's reply

print(assistant_reply)
# Out:
# [Your Name]
# [Your Address]
# [City, State, ZIP Code]
# [Email Address]
# [Phone Number]
# [Today's Date]
#
# [Company Name]
# [Company Address]
# [City, State, ZIP Code]
#
# Dear Hiring Manager,
#
# I am writing to express my strong interest in the Senior Data Analyst position at [Company Name], as advertised on [Job Portal/Company Website]. With a solid background in data analysis, programming, and a strong passion for utilizing data to drive meaningful insights, I am confident in my ability to contribute to [Company Name]'s data-driven decision-making processes.
#
# ...

# %%
messages += [
    {"role": "user", "content": requested_ammendment}
]


response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages,
)


assistant_reply = response['choices'][0]['message']['content']


print(assistant_reply)

# %%
# Define a conversation between you and the AI model
conversation = [
    {"role": "system", "content": "You are a helpful assistant that provides feedback on a job application."},
    {"role": "user", "content": "I have a CV and a job description, and I need a summary of how well my skills mentioned in my CV match the job requirements detailed in the job description. Can you break these down into 'Strengths' and 'Shortcomings'."},
    {"role": "assistant", "content": "Sure, please provide the CV and job description, and I'll help you with the summary."},
    {"role": "user", "content": f"Here's my CV: {cv}"},
    {"role": "assistant", "content": "Great, now please provide the job description."},
    {"role": "user", "content": f"Here's the job description: {job_description}"}
]

# Use OpenAI to generate a response
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=conversation
)

# Extract the AI's reply
ai_reply = response['choices'][0]['message']['content']

# Print the AI's response
print(ai_reply)
# Out:
# Thank you for providing the job description. Now, let's analyze how well your skills mentioned in your CV match the job requirements detailed in the job description.
#
# Strengths:
# - Relevant qualification: You have a Master of Data Science, which aligns with the requirement of a relevant qualification in information technology, S.T.E.M., statistics, data science/business analytics, or economics/econometrics.
# - Experience in data analytics methodologies and techniques: Your experience as a data engineering analyst and data analyst programmer showcases your expertise in data analytics methodologies and techniques.
# - Experience with programming languages: Your proficiency in Python programming aligns with the requirement for experience in programming languages.
# ...
